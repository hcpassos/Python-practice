# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Relação entre Idade e Custo
idcus = np.array([[18,871],[23,1132],[28,1242],[33,1356],[38,1488],[43,1638],[48,2130],[53,2454],[58,3066],[63,4090]])

planilha = pd.DataFrame({'Idade':idcus[:,0],'Custo':idcus[:,1]})

# %%
plt.scatter(planilha['Idade'],planilha['Custo'])

# %%
plt.plot(planilha)
